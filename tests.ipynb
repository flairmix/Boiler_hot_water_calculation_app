# %%
from boiler_hours import Boiler
import pandas as pd

# %%
pd.options.display.max_columns = 0
pd.set_option('display.expand_frame_repr', False)

# %%
consumption_1 = [-0.487, -0.487, -0.487, -0.487, -0.487,
                -5.44, -13.869, -13.869, -5.44, -5.44,
                -5.44, -4.65, -4.65, -4.65, -4.65,
                -5.137, -5.44, -5.44, -13.869, -13.869,
                -5.44, -5.44, -5.44, -5.44
                ]

boiler_1 = Boiler(
                name ="расчет_1",
                boiler_power_kW = 600,
                power_recircle_kW = 193,
                boiler_volume_m3 = 20,
                hw_reserve_init = 20,
                days = 3,
                consumption_by_hours_24 = consumption_1,
                tw1 = 10,
                t3 = 65,
                t4 = 55,
                t3_boiler = 65)

# %%
boiler_1.calculate()
# Out:
# self.consumption_by_hours_24_65 - [-0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44, -0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44, -0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44]
# len self.consumption_by_hours_24_65 - 72
# self.consumption_by_hours_24 - [-0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44, -0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44, -0.487, -0.487, -0.487, -0.487, -0.487, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -4.65, -4.65, -4.65, -4.65, -5.137, -5.44, -5.44, -13.869, -13.869, -5.44, -5.44, -5.44, -5.44]
# len self.consumption_by_hours_24 - 72
# self.hw_reserve - [20, 19.513, 19.026, 18.539, 18.052, 12.612, -1.257, -15.126, -20.566, -26.006, -31.446, -36.096, -40.746, -45.396, -50.046, -55.183, -60.623, -66.063, -79.932, -93.801, -99.241, -104.681, -110.121, -115.561, -116.048, -116.535, -117.022, -117.509, -117.996, -123.436, -137.305, -151.174, -156.614, -162.054, -167.494, -172.144, -176.794, -181.444, -186.094, -191.231, -196.671, -202.111, -215.98, -229.849, -235.289, -240.729, -246.169, -251.609, -252.096, -252.583, -253.07, -253.557, -254.044, -259.484, -273.353, -287.222, -292.662, -298.102, -303.542, -308.192, -312.842, -317.492, -322.142, -327.279, -332.719, -338.159, -352.028, -365.897, -371.337, -376.777, -382.217, -387.657]
# len self.hw_reserve - 72
# self.boiler_heating_G - 6.36
# self.hw_reserve_and_boil - [20, 20, 20, 20, 20, 20, 12.49, 4.98, 5.9, 6.82, 7.74, 9.45, 11.16, 12.87, 14.58, 15.8, 16.72, 17.64, 10.13, 2.62, 3.54, 4.46, 5.38, 6.3, 12.17, 18.04, 20, 20, 20, 20, 12.49, 4.98, 5.9, 6.82, 7.74, 9.45, 11.16, 12.87, 14.58, 15.8, 16.72, 17.64, 10.13, 2.62, 3.54, 4.46, 5.38, 6.3, 12.17, 18.04, 20, 20, 20, 20, 12.49, 4.98, 5.9, 6.82, 7.74, 9.45, 11.16, 12.87, 14.58, 15.8, 16.72, 17.64, 10.13, 2.62, 3.54, 4.46, 5.38, 6.3]
# len self.hw_reserve_and_boil - 72

# %%
boiler_1.print_report()
# Out:
# Исходные данные
# Объем бойлера - 20 м3
# Мощность нагрева бойлера - 600 кВт
# Нагрузка ГВС макс.час - 0 кВт
# Нагрузка ГВС ср.час - 0 кВт
# Нагрузка ГВС циркуляции - 193 кВт
# температура ГВС Т3 - 65
# температура ГВС Т4 - 55
# температура ГВС B1 - 10
# Рассматриваемый промежуток времени 72 ч
# Расчет выполняется по формулам :
# объем нагреваемой воды_м3 = (Мощность нагревателя_кВт - Мощность на нагрев циркуляции_кВт) / 1.163 / (Температура_65 - Температура_5)
# запас горячей воды_м3 = (резерв горячей воды - расход горячей воды + объем нагреваемой воды

# %%
boiler_1.create_df()

# %%
boiler_1.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Резерв ГВС в начале часа, м3/ч  72 non-null     float64
#  1   Расход_65гр, м3/ч               72 non-null     float64
#  2   Нагрев, м3/ч                    72 non-null     float64
#  3   Резерв ГВС в конце часа, м3/ч   72 non-null     float64
# dtypes: float64(4)
# memory usage: 2.8 KB

# %%
boiler_1.data['Расход_65гр, м3/ч'].head(24)
# Out:
# час
# 0     -0.487
# 1     -0.487
# 2     -0.487
# 3     -0.487
# 4     -0.487
# 5     -5.440
# 6    -13.869
# 7    -13.869
# 8     -5.440
# 9     -5.440
# 10    -5.440
# 11    -4.650
# 12    -4.650
# 13    -4.650
# 14    -4.650
# 15    -5.137
# 16    -5.440
# 17    -5.440
# 18   -13.869
# 19   -13.869
# 20    -5.440
# 21    -5.440
# 22    -5.440
# 23    -5.440
# Name: Расход_65гр, м3/ч, dtype: float64

# %%
boiler_1.data['Расход_65гр, м3/ч'][24:48:1]
# Out:
# час
# 24    -0.487
# 25    -0.487
# 26    -0.487
# 27    -0.487
# 28    -0.487
# 29    -5.440
# 30   -13.869
# 31   -13.869
# 32    -5.440
# 33    -5.440
# 34    -5.440
# 35    -4.650
# 36    -4.650
# 37    -4.650
# 38    -4.650
# 39    -5.137
# 40    -5.440
# 41    -5.440
# 42   -13.869
# 43   -13.869
# 44    -5.440
# 45    -5.440
# 46    -5.440
# 47    -5.440
# Name: Расход_65гр, м3/ч, dtype: float64

# %%
boiler_1.data['Расход_65гр, м3/ч'][48:72:1]
# Out:
# час
# 48    -0.487
# 49    -0.487
# 50    -0.487
# 51    -0.487
# 52    -0.487
# 53    -5.440
# 54   -13.869
# 55   -13.869
# 56    -5.440
# 57    -5.440
# 58    -5.440
# 59    -4.650
# 60    -4.650
# 61    -4.650
# 62    -4.650
# 63    -5.137
# 64    -5.440
# 65    -5.440
# 66   -13.869
# 67   -13.869
# 68    -5.440
# 69    -5.440
# 70    -5.440
# 71    -5.440
# Name: Расход_65гр, м3/ч, dtype: float64

# %%
boiler_1.print_df()
# Out:
#      Резерв ГВС в начале часа, м3/ч  Расход_65гр, м3/ч  Нагрев, м3/ч  Резерв ГВС в конце часа, м3/ч
# час
# 0                             12.00             -0.487          6.36                          20.00
# 1                             20.00             -0.487          6.36                          20.00
# 2                             20.00             -0.487          6.36                          20.00
# 3                             20.00             -0.487          6.36                          20.00
# 4                             20.00             -0.487          6.36                          20.00
# ..                              ...                ...           ...                            ...
# 67                            10.13            -13.869          6.36                           2.62
# 68                             2.62             -5.440          6.36                           3.54
# 69                             3.54             -5.440          6.36                           4.46
# 70                             4.46             -5.440          6.36                           5.38
# 71                             5.38             -5.440          6.36                           6.30
#
# [72 rows x 4 columns]

# %%
boiler_1.data.head(10)
# Out:
#      Резерв ГВС в начале часа, м3/ч  Расход_65гр, м3/ч  Нагрев, м3/ч  Резерв ГВС в конце часа, м3/ч
# час
# 0                             12.00             -0.487          6.36                          20.00
# 1                             20.00             -0.487          6.36                          20.00
# 2                             20.00             -0.487          6.36                          20.00
# 3                             20.00             -0.487          6.36                          20.00
# 4                             20.00             -0.487          6.36                          20.00
# 5                             20.00             -5.440          6.36                          20.00
# 6                             20.00            -13.869          6.36                          12.49
# 7                             12.49            -13.869          6.36                           4.98
# 8                              4.98             -5.440          6.36                           5.90
# 9                              5.90             -5.440          6.36                           6.82

# %%
# boiler_1.df_save()

# %%
boiler_1.plot_boiler()
